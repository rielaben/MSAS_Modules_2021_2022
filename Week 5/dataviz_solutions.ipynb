# %% [markdown]
# # **DATA VISUALIZATION INTRO**

# %% [markdown]
# [matplotlib.pyplot documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html)\
# Click on above link for supported commands, click on individual command for more details\
# [Greek Letter/TeX Syntax](https://www.mathworks.com/help/matlab/creating_plots/greek-letters-and-special-characters-in-graph-text.html)\
# Click on the above link for syntax for greek letters and other special characters (TeX Syntax)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### **Plot, Subplot Demos**
# [Line Graph Documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot)

# %%
x = np.linspace(-3, 3, 25) #linearly spaced interval w 25 points ranging from -3 to 3
#np.linspace(start, stop, num_steps)
y = x + 4
z = x**2 + 3
plt.figure()
plt.plot(x, y, label='y')
plt.plot(x, np.exp(x), label='$e^{x}$')
plt.plot(x, z, label='z')
plt.xlabel(r'$X$')
plt.ylabel('Y')
plt.title('Line Graph Demo')
plt.legend()
plt.show()
#plt.savefig('myfig.png')

# %% [markdown]
# [Box and Whisker Plot Documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.boxplot.html#matplotlib.pyplot.boxplot)\
# [Histogram Documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.contour.html#matplotlib.pyplot.contour)\
# [Box Plot Demo](https://matplotlib.org/stable/gallery/pyplots/boxplot_demo_pyplot.html)

# %%
x = np.random.randn(10000) + 25
fig, axs = plt.subplots(1, 2, figsize = (10, 5))
axs[0].hist(x, bins=100, label='distribution')
axs[0].set_ylabel('Frequency')
axs[0].set_xlabel('Sample Value')
axs[0].set_title('Histogram Demo')
axs[0].axvline(x=np.mean(x), color='red', label='mean')
axs[0].axvline(x=np.mean(x) + 2*np.std(x), color='red', linestyle='--', label='$\pm 2\sigma$')
axs[0].axvline(x=np.mean(x) - 2*np.std(x), color='red', linestyle='--')
axs[0].legend()
axs[1].boxplot(x)
axs[1].set_title('Box and Whisker Demo')
axs[1].set_ylabel('Sample Value')
axs[1].set_xticklabels([])
plt.suptitle('Subplot Demo')
plt.show()

# %% [markdown]
# [Scatter Plot Documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html#matplotlib.pyplot.scatter)

# %%
x = np.linspace(0, 26, 25) + 1950
y1 = np.random.randn(len(x)) + 24
y2 = (2/7)*(np.random.randn(len(x)) + x - 1935)
fig, axs = plt.subplots(2, 1, figsize = (5, 10))
axs[0].scatter(x, y1)
axs[0].set_xlabel(r' Xval $(Input)$')
axs[0].set_ylabel(r'Yval $(Output)$')
axs[0].set_title('Scatter Title')
axs[1].plot(x, y2, 'o')
axs[1].set_xlabel(r'Xval $(Input)$')
axs[1].set_ylabel(r'Yval $(Output)$')
axs[1].set_title('Plot Title')
plt.suptitle('Scatter Plot Demo')
plt.show()

# %% [markdown]
# Just because your data looks like nonsense does not mean it is not valuable!
# \
# Showing no correlation can be as helpful as showing correlation

# %% [markdown]
# **Other Simple Chart Documentations**\
# [Bar Chart Documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html#matplotlib.pyplot.bar)&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[Bar Chart Demo](https://matplotlib.org/stable/gallery/lines_bars_and_markers/barchart.html)\
# [Pie Chart Documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.pie.html#matplotlib.pyplot.pie)&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[Pie Chart Demo](https://matplotlib.org/stable/gallery/pie_and_polar_charts/pie_features.html?highlight=pie)\
# [Table Documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.table.html#matplotlib.pyplot.table)

# %% [markdown]
# Let's take a look at our data!

# %%
passing = pd.read_csv("https://raw.githubusercontent.com/rielaben/MSAS_Modules_2021_2022/main/Week%202/nfl_passing_2020.csv")

# %%
# PRELIMINARY DATA CLEANSING
strip = lambda char: passing['Player'].str.replace(char, '')
passing['Player'] = strip('*')
passing['Player'] = strip('+')
passing['Pos'] = passing['Pos'].str.upper()
passing.rename({'Tm' : 'Team',
                  'Pos': 'Position',
                  'G' : 'Games Played',
                  'Yds':'Yards',
                  'TD':'Touchdowns',
                  'Int':'Interceptions',
                  'Sk' :'Sacks'
},axis=1, inplace=True)

# %%
starting_qbs = passing[(passing['GS']>5) & (passing['Position']=='QB')][['Player', 'Team', 'Age', 'Cmp', 'Att', 'Yards', 'Touchdowns', 'Interceptions', 'Sacks', 'QBR']]
starting_qbs.head(5)
# Out:
#             Player Team  Age  Cmp  ...  Touchdowns  Interceptions  Sacks   QBR
# 0   Deshaun Watson  HOU   25  382  ...          33              7     49  70.5
# 1  Patrick Mahomes  KAN   25  390  ...          38              6     22  82.9
# 2        Tom Brady  TAM   43  401  ...          40             12     21  72.5
# 3        Matt Ryan  ATL   35  407  ...          26             11     41  67.0
# 4       Josh Allen  BUF   24  396  ...          37             10     26  81.7
#
# [5 rows x 10 columns]

# %%
starting_qbs['Cmp%'] = starting_qbs['Cmp']/starting_qbs['Att']
starting_qbs['TD/INT'] = starting_qbs['Touchdowns']/starting_qbs['Interceptions']

# %%
qbs_under_25 = starting_qbs[starting_qbs['Age'] < 25].sort_values(by='Cmp%', ascending=False).reset_index(drop=True)[:10]

# %% [markdown]
# [Styler documentation](https://pandas.pydata.org/docs/reference/api/pandas.io.formats.style.Styler.html#pandas.io.formats.style.Styler)

# %%
disp1 = qbs_under_25.rename({'TD/INT' : 'Touchdown to Interception Ratio',
                  'Cmp%': 'Completion Percentage',
},axis=1)
disp1 = disp1[['Player', 'Touchdown to Interception Ratio', 'Completion Percentage', 'QBR']]
disp1 = disp1.style.bar(subset=['Completion Percentage'], align='left', color=['#d65f5f', '#5fba7d'])
disp1 = disp1.bar(subset=['Touchdown to Interception Ratio'], align='mid', color=['#d65f5f', '#5fba7d'])
disp1 = disp1.background_gradient(subset=['QBR'], cmap='Blues')
disp1 = disp1.set_caption('Quarterbacks Under 25 Years Old <br> Average Completion Percentage = {0}%'.format(round(100*qbs_under_25['Cmp%'].mean(), 2)))
disp1 = disp1.hide_index()
disp1
# Out:
# <style  type="text/css" >
# #T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row0_col1,#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row0_col3{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 58.6%, transparent 58.6%);
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 78.9%, transparent 78.9%);
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row1_col3{
#             background-color:  #2171b5;
#             color:  #f1f1f1;
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 83.8%, transparent 83.8%);
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 72.2%, transparent 72.2%);
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row2_col3{
#             background-color:  #1f6eb3;
#             color:  #f1f1f1;
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.5%, transparent 86.5%);
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 67.0%, transparent 67.0%);
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row3_col3{
#             background-color:  #91c3de;
#             color:  #000000;
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 70.3%, transparent 70.3%);
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 59.6%, transparent 59.6%);
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row4_col3{
#             background-color:  #6caed6;
#             color:  #000000;
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 78.1%, transparent 78.1%);
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 49.4%, transparent 49.4%);
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row5_col3{
#             background-color:  #0e59a2;
#             color:  #f1f1f1;
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 59.5%, transparent 59.5%);
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 47.0%, transparent 47.0%);
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row6_col3{
#             background-color:  #8abfdd;
#             color:  #000000;
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 29.7%, transparent 29.7%);
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 30.0%, transparent 30.0%);
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row7_col3{
#             background-color:  #4997c9;
#             color:  #000000;
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 19.3%, transparent 19.3%);
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 18.7%, transparent 18.7%);
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row8_col3{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row9_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 22.1%, transparent 22.1%);
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row9_col2{
#             width:  10em;
#              height:  80%;
#         }#T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row9_col3{
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }</style><table id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002" class="dataframe"><caption>Quarterbacks Under 25 Years Old <br> Average Completion Percentage = 64.64%</caption><thead>    <tr>        <th class="col_heading level0 col0" >Player</th>        <th class="col_heading level0 col1" >Touchdown to Interception Ratio</th>        <th class="col_heading level0 col2" >Completion Percentage</th>        <th class="col_heading level0 col3" >QBR</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row0_col0" class="data row0 col0" >Josh Allen</td>
#                         <td id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row0_col1" class="data row0 col1" >3.700000</td>
#                         <td id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row0_col2" class="data row0 col2" >0.692308</td>
#                         <td id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row0_col3" class="data row0 col3" >81.700000</td>
#             </tr>
#             <tr>
#                                 <td id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row1_col0" class="data row1 col0" >Kyler Murray</td>
#                         <td id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row1_col1" class="data row1 col1" >2.166667</td>
#                         <td id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row1_col2" class="data row1 col2" >0.672043</td>
#                         <td id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row1_col3" class="data row1 col3" >68.900000</td>
#             </tr>
#             <tr>
#                                 <td id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row2_col0" class="data row2 col0" >Justin Herbert</td>
#                         <td id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row2_col1" class="data row2 col1" >3.100000</td>
#                         <td id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row2_col2" class="data row2 col2" >0.665546</td>
#                         <td id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row2_col3" class="data row2 col3" >69.500000</td>
#             </tr>
#             <tr>
#                                 <td id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row3_col0" class="data row3 col0" >Gardner Minshew II</td>
#                         <td id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row3_col1" class="data row3 col1" >3.200000</td>
#                         <td id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row3_col2" class="data row3 col2" >0.660550</td>
#                         <td id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row3_col3" class="data row3 col3" >51.700000</td>
#             </tr>
#             <tr>
#                                 <td id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row4_col0" class="data row4 col0" >Joe Burrow</td>
#                         <td id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row4_col1" class="data row4 col1" >2.600000</td>
#                         <td id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row4_col2" class="data row4 col2" >0.653465</td>
#                         <td id="T_a6122e2e_4832_11ec_bb8e_0242ac1c0002row4_co

# %% [markdown]
# How would you create a bar graph representing AFC North Touchdowns and Interceptions? \
# Let's look at the demo for help!

# %%
afc_north_qbs = starting_qbs[(starting_qbs['Team'].isin(['GNB', 'DET', 'CHI', 'MIN']))]
afc_north_qbs
# Out:
#                Player Team  Age  Cmp  ...  Sacks   QBR      Cmp%    TD/INT
# 6       Aaron Rodgers  GNB   37  372  ...     20  84.4  0.707224  9.600000
# 7        Kirk Cousins  MIN   32  349  ...     39  63.2  0.676357  2.692308
# 11   Matthew Stafford  DET   32  339  ...     38  68.4  0.642045  2.600000
# 30  Mitchell Trubisky  CHI   26  199  ...     18  61.3  0.670034  2.000000
# 32         Nick Foles  CHI   31  202  ...     18  43.3  0.647436  1.250000
#
# [5 rows x 12 columns]

# %%
afc_north_qbs.columns
# Out:
# Index(['Player', 'Team', 'Age', 'Cmp', 'Att', 'Yards', 'Touchdowns',
#        'Interceptions', 'Sacks', 'QBR', 'Cmp%', 'TD/INT'],
#       dtype='object')

# %%
labels = afc_north_qbs['Player']
tds = afc_north_qbs['Touchdowns']/afc_north_qbs['Att']
ints = afc_north_qbs['Interceptions']/afc_north_qbs['Att']

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

plt.figure(figsize=(9,6))
plt.bar(x - width/2, tds, width, label='Touchdowns Per Attempt')
plt.bar(x + width/2, ints, width, label='Interceptions Per Attempt')

# Add some text for labels, title and custom x-axis tick labels, etc.
plt.title('AFC North TD, INT Comparison')
plt.xticks(x, labels)
plt.legend()

plt.show()

# %% [markdown]
# The below code block shows how to create line plots. If you are dealing with any kind of data that changes over time and you want to visualize it, then you're probably going to want to use a lineplot. The first time running this cell will produce an ugly graph, but once you uncomment the appropriate lines you'll see how important some basic Matplotlib function can turn it into a real, usable graph. Try messing around with some of this code (comment/uncomment different lines, see what happens), also, try to add something new to the graph by finding something online (change line shape, graph_type, color, dimensions, etc.)

# %%
from matplotlib.pyplot import figure

# sets size of figure
figure(figsize=(12, 8))

# import data
# try running this line instead, try to understand why I made the line of code I did on line 9
# tom_brady_2007 = pd.read_csv("https://raw.githubusercontent.com/rielaben/MSAS_Modules_2021_2022/main/Week%205/tom_brady.csv")
# display(tom_brady_2007)
tom_brady_2007 = pd.read_csv("https://raw.githubusercontent.com/rielaben/MSAS_Modules_2021_2022/main/Week%205/tom_brady.csv", skiprows=1)[:-1]
display(tom_brady_2007)

# create line plot with Game on x axis and Yrds on y axis
plt.plot(tom_brady_2007['Date'], tom_brady_2007['Yds'])

# set y-limit of graph
# matplotlib will assume y_limits based on data, unless you set parameters
# in this sitation, we want to set minimum yards to 0 (just makes sense looking at football stats)

# run this cell first with it commented, then uncomment this
plt.ylim(0, 500)

# ALWAYS remember to include titles for you axes
plt.title("2007 Tom Brady Passing Yards By Game:")
plt.xlabel("Game Date")

# uncommenting this line fills the areas below the line in blue:
# plt.fill_between(tom_brady_2007['Date'], tom_brady_2007['Yds'], alpha=0.7)
# uncommenting this line creates a grid with the graph:
# plt.grid(True)

# uncomment this to see the dates in a redable way
plt.xticks(rotation=45)
plt.ylabel("Yards")
plt.show()
# Out:
#       Rk        Date    G#  Week     Age   Tm  ... Fmb   FL FF FR  Yds.3  TD.3
# 0    1.0    9/9/2007   1.0   1.0  30.037  NWE  ...   0  NaN  0  0      0     0
# 1    2.0   9/16/2007   2.0   2.0  30.044  NWE  ...   1  0.0  0  1      0     0
# 2    3.0   9/23/2007   3.0   3.0  30.051  NWE  ...   1  1.0  0  0      0     0
# 3    4.0   10/1/2007   4.0   4.0  30.059  NWE  ...   0  NaN  0  0      0     0
# 4    5.0   10/7/2007   5.0   5.0  30.065  NWE  ...   0  NaN  0  0      0     0
# 5    6.0  10/14/2007   6.0   6.0  30.072  NWE  ...   1  1.0  0  0      0     0
# 6    7.0  10/21/2007   7.0   7.0  30.079  NWE  ...   0  NaN  0  0      0     0
# 7    8.0  10/28/2007   8.0   8.0  30.086  NWE  ...   1  1.0  0  0      0     0
# 8    9.0   11/4/2007   9.0   9.0  30.093  NWE  ...   0  NaN  0  0      0     0
# 9   10.0  11/18/2007  10.0  11.0  30.107  NWE  ...   0  NaN  0  0      0     0
# 10  11.0  11/25/2007  11.0  12.0  30.114  NWE  ...   0  NaN  0  0      0     0
# 11  12.0   12/3/2007  12.0  13.0  30.122  NWE  ...   0  NaN  0  0      0     0
# 12  13.0   12/9/2007  13.0  14.0  30.128  NWE  ...   1  0.0  0  0      0     0
# 13  14.0  12/16/2007  14.0  15.0  30.135  NWE  ...   0  NaN  0  0      0     0
# 14  15.0  12/23/2007  15.0  16.0  30.142  NWE  ...   1  1.0  0  0      0     0
# 15  16.0  12/29/2007  16.0  17.0  30.148  NWE  ...   0  NaN  0  0      0     0
#
# [16 rows x 33 columns]

# %% [markdown]
# **Try it yourself!**
# \
# Ideas: \
# *   Pie Chart Comparing Cmp% vs Incmp%
#     - Reference pie chart demo
#     - Pick a player or some subset of players!
# *   Histogram Showing Distribution Y/A, Y/C, Y/G, etc... from big dataset
#     - How do we filter the outliers!
# *   Scatter plot showing correlation between 2 stats
# *   Download as CSV from [this database](https://www.pro-football-reference.com/years/NFL/index.htm) and analyze trends over time (Line Graph)
#     - This will take time
#     - Requires data cleansing
#     - What are you trying to analyze !
# *   Be creative!
#     - Play with colors, fonts, layouts, labels, subplots, designs, etc
#     - Recreate some code from above with different data

# %%
labels = ['Completed Passes', 'Incomplete Passes']
nfc_east_qbs = starting_qbs[(starting_qbs['Team'].isin(['WAS', 'NYG', 'DAL', 'PHI']))]
sizes = [nfc_east_qbs['Cmp'].sum()/nfc_east_qbs['Att'].sum(), 1 - nfc_east_qbs['Cmp'].sum()/nfc_east_qbs['Att'].sum()]

plt.figure()
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('AFC North 2020 Completion Percentage')

plt.show()

# %%
plt.figure()
plt.hist(qbs['Y/C'], bins=8)
plt.xlabel('Yards Per Completion')
plt.ylabel(r'$Frequency$')
plt.title('2020 QB Y/C Distribution')
plt.axvline(qbs['Y/C'].mean(), color='red', linestyle='--', label='average = {0} Y/C'.format(round(qbs['Y/C'].mean(), 2)))
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-63df6667f66c> in <module>()
#       1 plt.figure()
# ----> 2 plt.hist(qbs['Y/C'], bins=8)
#       3 plt.xlabel('Yards Per Completion')
#       4 plt.ylabel(r'$Frequency$')
#       5 plt.title('2020 QB Y/C Distribution')
#
# NameError: name 'qbs' is not defined
