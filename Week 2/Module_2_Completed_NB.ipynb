# %% [markdown]
# # **MSAS Tutorial 2**
# ##**Authored by Benjamin (Ben) Riela**

# %% [markdown]
# Today we will be working with Dataframes, the main way data is processed and manipulated in Python analytics

# %% [markdown]
# The first step we need to do is import the pandas library, which is the library used for working with dataframes. This library is essential to most Python analytics and for this module series

# %% [markdown]
# "Import" simply means bring in the pandas library, and we are calling this 'pd' (industry naming convention)

# %%
import pandas as pd

# %% [markdown]
# Click on the link: what do you see?
# What do you think CSV means, why would it be used to store data?

# %%
#reads csv file into dataframe
df = pd.read_csv("https://raw.githubusercontent.com/rielaben/MSAS_Modules_2021_2022/main/Week%202/nfl_passing_2020.csv")

print(df)
# Out:
#       Rk            Player   Tm  Age  Pos  ...   Y/C    Y/G   Rate   QBR  Sk
# 0      1   Deshaun Watson*  HOU   25   QB  ...  12.6  301.4  112.4  70.5  49
# 1      2  Patrick Mahomes*  KAN   25   QB  ...  12.2  316.0  108.2  82.9  22
# 2      3         Tom Brady  TAM   43   QB  ...  11.6  289.6  102.2  72.5  21
# 3      4         Matt Ryan  ATL   35   QB  ...  11.3  286.3   93.3  67.0  41
# 4      5       Josh Allen*  BUF   24   QB  ...  11.5  284.0  107.2  81.7  26
# ..   ...               ...  ...  ...  ...  ...   ...    ...    ...   ...  ..
# 107  108        Brett Kern  TEN   34  NaN  ...   NaN    0.0   39.6   0.0   0
# 108  109        D.J. Moore  CAR   23   WR  ...   NaN    0.0   39.6   NaN   0
# 109  110       Zach Pascal  IND   26   WR  ...   NaN    0.0   39.6   2.5   0
# 110  111     Sammy Watkins  KAN   27   WR  ...   NaN    0.0    0.0   0.0   0
# 111  112     Isaiah Wright  WAS   23   wr  ...   NaN    0.0   39.6   3.8   0
#
# [112 rows x 20 columns]

# %% [markdown]
# Display shows output in a nice format, we use this more often than just calling "print"

# %%
display(df.head(3))
# Out:
#    Rk            Player   Tm  Age Pos   G  ...  Y/A   Y/C    Y/G   Rate   QBR  Sk
# 0   1   Deshaun Watson*  HOU   25  QB  16  ...  8.9  12.6  301.4  112.4  70.5  49
# 1   2  Patrick Mahomes*  KAN   25  QB  15  ...  8.1  12.2  316.0  108.2  82.9  22
# 2   3         Tom Brady  TAM   43  QB  16  ...  7.6  11.6  289.6  102.2  72.5  21
#
# [3 rows x 20 columns]

# %% [markdown]
# Now we can start to dig into the actual data
# What do you think this code below does?

# %%
df.shape
# Out:
# (112, 20)

# %% [markdown]
# This outputs all of the columns present in the dataframe:

# %%
df.columns
# Out:
# Index(['Rk', 'Player', 'Tm', 'Age', 'Pos', 'G', 'GS', 'Cmp', 'Att', 'Cmp%',
#        'Yds', 'TD', 'Int', '1D', 'Y/A', 'Y/C', 'Y/G', 'Rate', 'QBR', 'Sk'],
#       dtype='object')

# %% [markdown]
# What do you think this means?

# %%
df.dtypes
# Out:
# Rk          int64
# Player     object
# Tm         object
# Age         int64
# Pos        object
# G           int64
# GS          int64
# Cmp         int64
# Att         int64
# Cmp%      float64
# Yds         int64
# TD          int64
# Int         int64
# 1D          int64
# Y/A       float64
# Y/C       float64
# Y/G       float64
# Rate      float64
# QBR       float64
# Sk          int64
# dtype: object

# %% [markdown]
# Calling .tail() shows the last n rows of your dataframe:

# %% [markdown]
# What looks weird in the table below?

# %%
display(df.tail(20))
# Out:
#       Rk           Player   Tm  Age  Pos   G  ...   Y/A   Y/C   Y/G   Rate   QBR  Sk
# 92    93        Greg Ward  PHI   25   wr  16  ...  15.0  15.0   0.9  118.7   0.9   0
# 93    94   Kendall Hinton  DEN   23  NaN   1  ...   1.4  13.0  13.0    0.0   0.1   1
# 94    95   Jaquan Johnson  BUF   25  NaN  14  ...  13.0  13.0   0.9  118.7   NaN   0
# 95    96   Tommy Townsend  KAN   24  NaN  16  ...  13.0  13.0   0.8  118.7  13.9   0
# 96    97  Isaiah McKenzie  BUF   25   wr  16  ...  12.0  12.0   0.8  156.2  91.0   0
# 97    98   Logan Woodside  TEN   25  NaN   6  ...   2.3   7.0   1.2   42.4  71.7   0
# 98    99   Travis Kelce*+  KAN   31   TE  15  ...   2.0   4.0   0.3   56.2  62.7   0
# 99   100     Easton Stick  LAC   25  NaN   1  ...   4.0   4.0   4.0   83.3   1.8   0
# 100  101     Joshua Dobbs  PIT   25  NaN   1  ...   0.4   0.5   2.0   79.2  56.4   0
# 101  102      Jamal Agnew  DET   25  NaN  14  ...   0.0   NaN   0.0   39.6   1.3   0
# 102  103    Keenan Allen*  LAC   28   WR  14  ...   0.0   NaN   0.0   39.6   1.9   0
# 103  104     Randall Cobb  HOU   30  NaN  10  ...   0.0   NaN   0.0   39.6   3.8   0
# 104  105      Riley Dixon  NYG   27  NaN  16  ...   0.0   NaN   0.0   39.6   NaN   0
# 105  106    Alex Erickson  CIN   28  NaN  16  ...   0.0   NaN   0.0   39.6  11.1   0
# 106  107      Chris Jones  DAL   31  NaN   8  ...   0.0   NaN   0.0   39.6   NaN   0
# 107  108       Brett Kern  TEN   34  NaN  13  ...   0.0   NaN   0.0   39.6   0.0   0
# 108  109       D.J. Moore  CAR   23   WR  15  ...   0.0   NaN   0.0   39.6   NaN   0
# 109  110      Zach Pascal  IND   26   WR  16  ...   0.0   NaN   0.0   39.6   2.5   0
# 110  111    Sammy Watkins  KAN   27   WR  10  ...   0.0   NaN   0.0    0.0   0.0   0
# 111  112    Isaiah Wright  WAS   23   wr  14  ...   0.0   NaN   0.0   39.6   3.8   0
#
# [20 rows x 20 columns]

# %% [markdown]
# * In following modules, we will talk more about these irregularities in the data, and how to clean them before doing analyses

# %%
display(type(df))
display(type(df['Rate']))
# Out:
# pandas.core.frame.DataFrame
# pandas.core.series.Series

# %% [markdown]
# This is how you would isolate a column:

# %%
players_column = df[['TD']]
players_column.head()
# Out:
#    TD
# 0  33
# 1  38
# 2  40
# 3  26
# 4  37

# %% [markdown]
# This is how to isolate multiple columns:

# %%
new_df = df[['Player', 'Tm', 'Pos']]
new_df
# Out:
#                Player   Tm  Pos
# 0     Deshaun Watson*  HOU   QB
# 1    Patrick Mahomes*  KAN   QB
# 2           Tom Brady  TAM   QB
# 3           Matt Ryan  ATL   QB
# 4         Josh Allen*  BUF   QB
# ..                ...  ...  ...
# 107        Brett Kern  TEN  NaN
# 108        D.J. Moore  CAR   WR
# 109       Zach Pascal  IND   WR
# 110     Sammy Watkins  KAN   WR
# 111     Isaiah Wright  WAS   wr
#
# [112 rows x 3 columns]

# %% [markdown]
# Practice: create a dataframe only showing information for players, their completions, yards, touchdowns, and sacks.

# %%
new_df = df[['Player', 'Cmp', 'Yds', 'TD', 'Sk']]
new_df
# Out:
#                Player  Cmp   Yds  TD  Sk
# 0     Deshaun Watson*  382  4823  33  49
# 1    Patrick Mahomes*  390  4740  38  22
# 2           Tom Brady  401  4633  40  21
# 3           Matt Ryan  407  4581  26  41
# 4         Josh Allen*  396  4544  37  26
# ..                ...  ...   ...  ..  ..
# 107        Brett Kern    0     0   0   0
# 108        D.J. Moore    0     0   0   0
# 109       Zach Pascal    0     0   0   0
# 110     Sammy Watkins    0     0   0   0
# 111     Isaiah Wright    0     0   0   0
#
# [112 rows x 5 columns]

# %% [markdown]
# You can filter by certain qualifications by using the '[' and ']' operators

# %%
# df[df[''] < ]
# df[df[''] > ]
df[df['Player'] == 'Patrick Mahomes*']
# Out:
#    Rk            Player   Tm  Age Pos   G  ...  Y/A   Y/C    Y/G   Rate   QBR  Sk
# 1   2  Patrick Mahomes*  KAN   25  QB  15  ...  8.1  12.2  316.0  108.2  82.9  22
#
# [1 rows x 20 columns]

# %%
df[df['TD'] > 30]
# Out:
#     Rk              Player   Tm  Age Pos   G  ...  Y/A   Y/C    Y/G   Rate   QBR  Sk
# 0    1     Deshaun Watson*  HOU   25  QB  16  ...  8.9  12.6  301.4  112.4  70.5  49
# 1    2    Patrick Mahomes*  KAN   25  QB  15  ...  8.1  12.2  316.0  108.2  82.9  22
# 2    3           Tom Brady  TAM   43  QB  16  ...  7.6  11.6  289.6  102.2  72.5  21
# 4    5         Josh Allen*  BUF   24  QB  16  ...  7.9  11.5  284.0  107.2  81.7  26
# 5    6      Justin Herbert  LAC   22  QB  15  ...  7.3  10.9  289.1   98.3  69.5  32
# 6    7     Aaron Rodgers*+  GNB   37  QB  16  ...  8.2  11.6  268.7  121.5  84.4  20
# 7    8        Kirk Cousins  MIN   32  QB  16  ...  8.3  12.2  266.6  105.0  63.2  39
# 8    9     Russell Wilson*  SEA   32  QB  16  ...  7.5  11.0  263.3  105.1  73.5  47
# 14  15      Ryan Tannehill  TEN   32  QB  16  ...  7.9  12.1  238.7  106.5  78.3  24
# 15  16  Ben Roethlisberger  PIT   38  QB  15  ...  6.3   9.5  253.5   94.1  60.1  13
#
# [10 rows x 20 columns]

# %% [markdown]
# How would we isolate Tom Brady's stats for lat season?

# %%
df[df['Player'] == 'Tom Brady']
# Out:
#    Rk     Player   Tm  Age Pos   G  GS  ...   1D  Y/A   Y/C    Y/G   Rate   QBR  Sk
# 2   3  Tom Brady  TAM   43  QB  16  16  ...  233  7.6  11.6  289.6  102.2  72.5  21
#
# [1 rows x 20 columns]

# %% [markdown]
# Isolate Taysom Hill's stats - what looks weird?

# %%
df[df['Player'] == 'Taysom Hill']
# Out:
#     Rk       Player   Tm  Age Pos   G  GS  ...  1D  Y/A   Y/C   Y/G  Rate   QBR  Sk
# 39  40  Taysom Hill  NOR   30  wr  16   8  ...  45  7.7  10.5  58.0  98.8  58.8  14
#
# [1 rows x 20 columns]

# %% [markdown]
# How would we filter so we are just looking at Wide Recievers?

# %%
# in future tutorials we will learn how to standardize this so all values are "WR"
df[(df['Pos'] == 'WR')|(df['Pos'] == 'wr')]
# Out:
#       Rk             Player   Tm  Age Pos  ...   Y/C   Y/G   Rate    QBR  Sk
# 39    40        Taysom Hill  NOR   30  wr  ...  10.5  58.0   98.8   58.8  14
# 66    67      Jarvis Landry  CLE   28  WR  ...  18.5   4.9  158.3  100.0   0
# 69    70    Jamison Crowder  NYJ   27  WR  ...  43.0   3.6  158.3  100.0   0
# 70    71      Jakobi Meyers  NWE   24  wr  ...  21.5   3.1  158.3  100.0   0
# 72    73       Russell Gage  ATL   24  wr  ...  39.0   2.4  135.4  100.0   0
# 83    84       Cole Beasley  BUF   31  wr  ...  20.0   1.3  158.3  100.0   0
# 85    86  Odell Beckham Jr.  CLE   28  WR  ...  18.0   2.6  118.7   99.2   0
# 89    90         Tyler Boyd  CIN   26  wr  ...  16.0   1.1   77.1   55.7   0
# 92    93          Greg Ward  PHI   25  wr  ...  15.0   0.9  118.7    0.9   0
# 96    97    Isaiah McKenzie  BUF   25  wr  ...  12.0   0.8  156.2   91.0   0
# 102  103      Keenan Allen*  LAC   28  WR  ...   NaN   0.0   39.6    1.9   0
# 108  109         D.J. Moore  CAR   23  WR  ...   NaN   0.0   39.6    NaN   0
# 109  110        Zach Pascal  IND   26  WR  ...   NaN   0.0   39.6    2.5   0
# 110  111      Sammy Watkins  KAN   27  WR  ...   NaN   0.0    0.0    0.0   0
# 111  112      Isaiah Wright  WAS   23  wr  ...   NaN   0.0   39.6    3.8   0
#
# [15 rows x 20 columns]

# %%
df[df['Pos'] == 'WR']
# Out:
#       Rk             Player   Tm  Age Pos  ...   Y/C  Y/G   Rate    QBR  Sk
# 66    67      Jarvis Landry  CLE   28  WR  ...  18.5  4.9  158.3  100.0   0
# 69    70    Jamison Crowder  NYJ   27  WR  ...  43.0  3.6  158.3  100.0   0
# 85    86  Odell Beckham Jr.  CLE   28  WR  ...  18.0  2.6  118.7   99.2   0
# 102  103      Keenan Allen*  LAC   28  WR  ...   NaN  0.0   39.6    1.9   0
# 108  109         D.J. Moore  CAR   23  WR  ...   NaN  0.0   39.6    NaN   0
# 109  110        Zach Pascal  IND   26  WR  ...   NaN  0.0   39.6    2.5   0
# 110  111      Sammy Watkins  KAN   27  WR  ...   NaN  0.0    0.0    0.0   0
#
# [7 rows x 20 columns]

# %% [markdown]
# https://www.youtube.com/watch?v=WcX12X4Xw0c

# %% [markdown]
# Look up the sort_values function: Try to apply this to the dataframe:
#
# Who had the most passing yards last season?
# Who had the most sacks?
# Who had the most interceptions?

# %%
ranked_yards = df.sort_values(by=['Yds'], ascending=False)
ranked_yards.head()
# Out:
#    Rk            Player   Tm  Age Pos   G  ...  Y/A   Y/C    Y/G   Rate   QBR  Sk
# 0   1   Deshaun Watson*  HOU   25  QB  16  ...  8.9  12.6  301.4  112.4  70.5  49
# 1   2  Patrick Mahomes*  KAN   25  QB  15  ...  8.1  12.2  316.0  108.2  82.9  22
# 2   3         Tom Brady  TAM   43  QB  16  ...  7.6  11.6  289.6  102.2  72.5  21
# 3   4         Matt Ryan  ATL   35  QB  16  ...  7.3  11.3  286.3   93.3  67.0  41
# 4   5       Josh Allen*  BUF   24  QB  16  ...  7.9  11.5  284.0  107.2  81.7  26
#
# [5 rows x 20 columns]

# %% [markdown]
# Who had the highest completion percentage? What can we do to get a more accurate result?

# %%
# first want to start with QBS
qbs = df[df['Pos'] == 'QB']
# then sort values on Completion Percentage
qbs_cmp_pct = qbs.sort_values(by=['Cmp%'], ascending=False)
display(qbs_cmp_pct)
# Out:
#     Rk              Player   Tm  Age Pos   G  ...  Y/A   Y/C    Y/G   Rate   QBR  Sk
# 6    7     Aaron Rodgers*+  GNB   37  QB  16  ...  8.2  11.6  268.7  121.5  84.4  20
# 19  20          Drew Brees  NOR   41  QB  12  ...  7.5  10.7  245.2  106.4  74.6  13
# 0    1     Deshaun Watson*  HOU   25  QB  16  ...  8.9  12.6  301.4  112.4  70.5  49
# 4    5         Josh Allen*  BUF   24  QB  16  ...  7.9  11.5  284.0  107.2  81.7  26
# 16  17   Teddy Bridgewater  CAR   28  QB  15  ...  7.6  11.0  248.9   92.1  64.2  31
# 8    9     Russell Wilson*  SEA   32  QB  16  ...  7.5  11.0  263.3  105.1  73.5  47
# 9   10       Philip Rivers  IND   39  QB  16  ...  7.7  11.3  260.6   97.0  62.5  19
# 7    8        Kirk Cousins  MIN   32  QB  16  ...  8.3  12.2  266.6  105.0  63.2  39
# 10  11          Derek Carr  LVR   29  QB  16  ...  7.9  11.8  256.4  101.4  71.0  26
# 12  13       Kyler Murray*  ARI   23  QB  16  ...  7.1  10.6  248.2   94.3  68.9  27
# 13  14          Jared Goff  LAR   26  QB  15  ...  7.2  10.7  263.5   90.0  58.5  23
# 30  31   Mitchell Trubisky  CHI   26  QB  10  ...  6.9  10.3  205.5   93.5  61.3  18
# 34  35          Alex Smith  WAS   36  QB   8  ...  6.3   9.4  197.8   78.5  34.8  22
# 5    6      Justin Herbert  LAC   22  QB  15  ...  7.3  10.9  289.1   98.3  69.5  32
# 1    2    Patrick Mahomes*  KAN   25  QB  15  ...  8.1  12.2  316.0  108.2  82.9  22
# 26  27  Gardner Minshew II  JAX   24  QB   9  ...  6.9  10.5  251.0   95.9  51.7  27
# 23  24          Cam Newton  NWE   31  QB  15  ...  7.2  11.0  177.1   82.9  47.0  31
# 2    3           Tom Brady  TAM   43  QB  16  ...  7.6  11.6  289.6  102.2  72.5  21
# 15  16  Ben Roethlisberger  PIT   38  QB  15  ...  6.3   9.5  253.5   94.1  60.1  13
# 14  15      Ryan Tannehill  TEN   32  QB  16  ...  7.9  12.1  238.7  106.5  78.3  24
# 22  23          Joe Burrow  CIN   24  QB  10  ...  6.7  10.2  268.8   89.8  56.2  32
# 3    4           Matt Ryan  ATL   35  QB  16  ...  7.3  11.3  286.3   93.3  67.0  41
# 28  29         Andy Dalton  DAL   33  QB  11  ...  6.5  10.0  197.3   87.3  53.8  24
# 25  26        Nick Mullens  SFO   25  QB  10  ...  7.5  11.5  243.7   84.1  43.6  19
# 21  22       Lamar Jackson  BAL   23  QB  15  ...  7.3  11.4  183.8   99.3  73.7  29
# 11  12    Matthew Stafford  DET   32  QB  16  ...  7.7  12.0  255.3   96.3  68.4  38
# 33  34      Tua Tagovailoa  MIA   22  QB  10  ...  6.3   9.8  181.4   87.1  52.5  20
# 17  18      Baker Mayfield  CLE   25  QB  16  ...  7.3  11.7  222.7   95.9  72.2  26
# 18  19        Daniel Jones  NYG   23  QB  14  ...  6.6  10.5  210.2   80.4  61.5  45
# 27  28         Sam Darnold  NYJ   23  QB  12  ...  6.1  10.2  184.0   72.7  40.1  35
# 24  25        Carson Wentz  PHI   28  QB  12  ...  6.0  10.4  218.3   72.8  49.6  50
# 20  21           Drew Lock  DEN   24  QB  13  ...  6.6  11.5  225.6   75.4  48.8  19
#
# [32 rows x 20 columns]

# %% [markdown]
# Go mess around with this data - try out new things! Google is your best friend: if you get an error or don't know how to do something, ALWAYS Google it first.
